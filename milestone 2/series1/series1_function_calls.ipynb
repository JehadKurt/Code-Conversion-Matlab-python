# %% [markdown]
# # Series 1 Function Call codes

# %%
from series1 import conflevel
from series1 import conflevel1

# %%
conflevel(-2/3,100000,1000)
# Out:
# C:\Users\Jehad\Desktop\Upwork task\milestone 2\series1\series1.py:38: RuntimeWarning: divide by zero encountered in power

# %%
conflevel(-2/5,100000,1000)
# Out:
# C:\Users\Jehad\Desktop\Upwork task\milestone 2\series1\series1.py:38: RuntimeWarning: divide by zero encountered in power

# %%
conflevel1(100000, -2/3)
# Out:
# C:\Users\Jehad\Desktop\Upwork task\milestone 2\series1\series1.py:88: RuntimeWarning: divide by zero encountered in power

# %%
conflevel1(100000, -2/5)
# Out:
# C:\Users\Jehad\Desktop\Upwork task\milestone 2\series1\series1.py:88: RuntimeWarning: divide by zero encountered in power
