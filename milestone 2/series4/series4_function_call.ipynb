# %% [markdown]
# ### Series 4 with function call

# %%
from Series4 import sde_convstrongmil
from Series4 import sde_convweak
from Series4 import sde_convstrong
from Series4 import sde_heston2

# %%
sde_convstrong()
# Out:
# Strong rate of convergence error in L_1: 0.5043261322273296
# Strong rate of convergence error in L_2: 0.4912258643752467
# Elapsed time: 1.5396037101745605

# %%
sde_convstrongmil()
# Out:
# Strong rate of convergence: 0.9556027755050176
# Elapsed time: 3.9846904277801514

# %%
sde_convweak()
# Out:
# Weak rate of convergence L^2: 1.2299573926476157
# Weak rate of convergence L^1: 1.2307915340867766
# Elapsed time: 22.687206745147705

# %%
sde_heston2()
# Out:
# CLT confidence interval
# [[3.2947983  3.42179813]
#  [3.25684862 3.3808496 ]
#  [3.23948899 3.36222108]
#  [3.23157682 3.35362328]
#  [3.22988949 3.35162081]
#  [3.22941886 3.35100939]]
# Elapsed time: 5.997417449951172

# %%
# Out:
# Weak rate of convergence L^2: 1.0214014401263503
# Weak rate of convergence L^1: 1.0237249935743171
# Elapsed time: 21.637722969055176
