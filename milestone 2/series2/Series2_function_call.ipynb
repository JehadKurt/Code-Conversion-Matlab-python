# %% [markdown]
# # Series 2 Function call code

# %%
from GBM import GBM
from GBM import ex43a

# %%
GBM()
# Out:
# Estimated value: 2.6093136016832275
# Confidence interval: [2.6043264070922545, 2.6143007962742004]

# %%
ex43a()
